# %%
# Import our dependencies

import pandas as pd

# %%
application_df = pd.read_csv("Meteorite_Landings.csv")
application_df.head(10)
# Out:
#                   name   id nametype     recclass mass (g)  fall    year  \
# 0               Aachen    1    Valid           L5       21  Fell  1880.0
# 1               Aarhus    2    Valid           H6      720  Fell  1951.0
# 2                 Abee    6    Valid          EH4  107,000  Fell  1952.0
# 3             Acapulco   10    Valid  Acapulcoite    1,914  Fell  1976.0
# 4              Achiras  370    Valid           L6      780  Fell  1902.0
# 5             Adhi Kot  379    Valid          EH4    4,239  Fell  1919.0
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6      910  Fell  1949.0
# 7                 Agen  392    Valid           H5   30,000  Fell  1814.0
# 8               Aguada  398    Valid           L6    1,620  Fell  1930.0
# 9        Aguila Blanca  417    Valid            L    1,440  Fell  1920.0
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
# Final data - remove ID
